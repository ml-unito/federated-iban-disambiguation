# %%
import random
import numpy as np
import pandas as pd
import editdistance

# %%
names = [
    "AL CAUT AL RUTTI GEN TRD CO LLC POB",
    #"Al Caut Al Russi Gen Tr.Co.LLC",
    "DARK MOON BEACH RESORT LLC",
    #"FM FLOGARIE MARKT SRL",
    "FM FLOGERIE MARKET SRL",
    #"FL FLOGERIE MARKT S.R.L.",
    #"FL FLOGERIE MARKT SRL",
    #"FL FLOGHERIE MARKT SRL",
    #"CAPOVOLTA RO",
    #"CAPOVOLTA S.A.",
    "CAPOVOLTA SRL",
    #"POLDO",
    #"POLDO IMMOBILIARE S.R.L.",
    #"POLDO IMMOBILIARE SRL",
    #"POLDO SRL",
    "BNP PARIBAS SA, NIEDERLASSUNG OSTERREICH",
    "GIALDI SRL",
    #"GIALSI SRL",
    "CAR SALE NV",
    #"CAR SALE",
    #"GENIUS",
    #"GENIUS GENIUS",
    #"GENIUS ITALIA",
    #"GENIUS ITALIA S.R.L",
    #"GENIUS ITALIA S.R.L.",
    "GENIUS ITALIA SRL",
    #"#GENIUS SRL",
    #"GENIIUS ITALIA SRL",
    "BNP PARIBAS FORTIS",
    #"C040603 GENIUS ITALIA",
    "ECO MENTE SRL",
    #"ECOMENTE SRL",
    "BIDONI CONSULTING LLC",
    #"BIDDONI CONSULTING LLC",
    #"BIDDONI COLSUNTING LLC",
    #"BIDDONI CONSULTING LLC",
    #"BIDDONI COUNSOLTING LLC",
    #"CRAEM",
    #"CRAEM NV",
    #"CRAEM NV HANDZAAMSE NIEUWSTRAAT 18 20",
    "CRAEM NV SA",
    #"CRAEM NV SA BELGIE",
    #"CRAEM NV,SA",
    #"CRAEM NV,SA,",
    #"CRAEM NV-SA",
    #"CRAEM NV-SA,",
    #"CRAEM NV/SA",
    #"CRAEM NV/SA,",
    #"CRAEM NVSA",
    #"GLP",
    #"GLP ASSURANCES",
    #"GLP BRUSSELS",
    #"GLP INSURANCE N.V.",
    #"GLP INSURANCE NV",
    #"GLP INSURANCES",
    "GLP SNEDIKER GRAULICH SPRL",
    #"GLP VERZEKERING",
    #"GLP VERZEKERINGEN",
]


names = ['Roger Legrand S.A.R.L.', 
        'Krebs', 
        'Ropero y Ruano S.C', 
        'Gemito, Lippomano e Pellico e figli', 
        'Scholtz', 
        'Reesink', 
        'Wilmsen', 
        'Huet', 
        'Häring', 
        'Manufacturas Iberia S.L.U.', 
        'Pierre Joseph S.A.R.L.', 
        'Hendriks GbR', 
        'Wulf KG', 
        'Hecker Bolander GmbH', 
        'Fernandes', 
        'Jackson, Simpson and', 
        'Junk Eberhardt GmbH', 
        'Boulay', 
        'Jackson, Simpson-and Richards', 
        'Soranzo Group', 
        'Rohleder Zänker GmbH & Co. KG', 
        'Stadelmann', 
        'Andre', 
        'Jacques SARL', 'Clerc', 'Hnos Andreu', 'Schuster Stiftung. &', 'Buchholz GmbH', 'Schmitt et Fils', 'Fogaça', 'Dias', 'Gosselin S.A.S.', 'da Cunha S.A.', 'Stadelmann', 'Hnos Andreu S.a.', 'Ropero y Ruano-S.C', 'Karge Atzler AG & Corp KG', 'Hnos Andreu SAS', 'Hnos  Andreu-', 'Gemito, Lippomano. e Pellico.e figli', 'Gemito, Lippomano Pellico e figli', 'Roger Legrand  S.A.R.L.', 'Gemito,. Lippomano Pellico e/figli', 'Gemito,-Lippomano e Pellico e figli']

abbreviation_variations = [
    #"Corporation": 
    ["Corp.", "Corp", "Corpn.", "Cp."],
    
    #"Incorporated": 
    ["Inc.", "Inc", "Incorporated"],
    
    #"Limited": 
    ["Ltd.", "Ltd", "Limited", "Ltée", "LTD", "Ltd", "LTd.", "L.t.d.", "Ltd ", "LTT", "Ltd."],
    
    #"Company": 
    ["Co.", "Co", "Company", "Comp."],
    
    #"Private Limited": 
    ["P.L.C.", "Public Limited Company", "PLC ", "plc", "pLC", "PLCC", "P.L.C", "Pvt. Ltd.", "Pvt Ltd", "Pvt. Limited", "P.L.C.", "Public Ltd.", "Public", "Pvt. Ltd"],
    
    
    #"Società Italiane
    ["S.p.A.", "SpA", "S.P.A.", "SPA", "Sp.A.", "S.P.A", "Società per Azioni", "SpA ",],
    ["S.r.l.", "S.R.L.", "SRL", "S.r.L", "S r l", "Srl"],
    ["S.a.p.a.", "SAPA", "S.A.P.A.", "S.a.p.a", "S.A.P.A"],
    ["S.a.s.", "SAS", "S.A.S.", "S.a.s", "S.A.S"],
    ["S.c.", "S.C.", "SC", "S.c", "S.C"],
    ["S.a.", "SA", "S.A.", "S.a", "S.A"],
    ["S.c.a.r.l.", "S.C.A.R.L.", "SCARL", "S.c.a.r.l", "S.C.A.R.L", "S.A.R.L."],
    ["S.d.f.", "S.D.F.", "SDF", "S.d.f", "S.D.F"],
    ["S.u.", "S.U.", "SU", "S.u", "S.U"],
    ["S.N.C.", "SNC", "S.n.c", "S.N.C"],
]

Transcription_errors = ['.', ',', '-', '/', '- ', ". ", " .", " - "]
international_company_words = [
    "Group",
    "Corporation",
    "Holdings",
    "Enterprises",
    "International",
    "Global",
    "Solutions",
    "Services",
    "Technologies",
    "Industries",
    "Partners",
    "Systems",
    "Worldwide",
    "Ventures",
    "Enterprises",
    "Brothers",
    "Sons",
    "Company",
    "Associates",
    "Limited"
]

# %%
# Compute change abbreviations


name = "ECO MENTE SRL"
words = name.split()

def compute_variation_abbreviation(words, threshold):
  """ """
  newList = []
  for j in range(len(words)):
    selectedList = []
    for abbreviations in abbreviation_variations:
      abbrLower = [el.lower() for el in abbreviations]
      
      for ab in abbrLower:
        if editdistance.eval(words[j].lower(), ab) < threshold:
          index = abbrLower.index(ab)
          if selectedList == []: selectedList = [el for (i,el) in enumerate(abbreviations) if i != index]
          else: selectedList += [el for (i,el) in enumerate(abbreviations[:len(abbreviations) // 2]) if i != index]
                    
    if len(selectedList) > 0: newList.append((words[j], selectedList))

  return newList



def compute_transcription_errors(aliasList, newT):
  """ Introduce transcription errors based on T (Temperature) value """

  aliases = aliasList
  for j,alias in enumerate(aliases):
    
    word = list(alias)
    if len(alias.split()) > 1:
      voidPositions = [j for j,i in enumerate(word) if i == ' ']
      for i in voidPositions:
          if random.random() < newT: word[i] = random.choice(Transcription_errors)
    else:
      random_positions = random.sample(range(len(word)), random.randint(0, len(word) // 2))
      for i in random_positions:
          if random.random() < newT: word[i] = random.choice([el for el in Transcription_errors if el != "/"])

    aliases[j] = ''.join(word)

  return aliases


def introduce_variability(aliasList, abbrList):
  """  Introduce variability in companies abbreviations """

  aliases = aliasList
  for j,_ in enumerate(aliases):
    if len(abbrList) > 0:
      elem = random.choice(abbrList)
      elemList = random.choice(elem[1])
      if random.random() < V:
        aliases[j] = aliases[j].replace(elem[0], elemList)
      else:
          newAlias = aliases[j].split(elem[0])
          if newAlias[0] != "": aliases[j] = newAlias[0].strip()
          elif newAlias[1] != "": aliases[j] = newAlias[1].strip()
          else: continue
          
  return aliases


def introduce_white_spaces(aliasList, C):
  """ """

  aliases = aliasList
  # Add additional spaces
  for j,alias in enumerate(aliases):
    if random.random() < C:
      alias_with_spaces = list(alias)
      voidPositions = [k for k,q in enumerate(alias_with_spaces) if q == ' ']
      if len(voidPositions) > 0:
        el = random.choice(voidPositions)
        alias_with_spaces.insert(el, ' ')
        aliases[j] = ''.join(alias_with_spaces)
  
  return aliases
          

def introduce_new_words(aliasList, nameList, V):
  """ """

  aliases = aliasList
  addWord = ""
  for j,_ in enumerate(aliases):
    if random.random() < V:
      if addWord == "": addWord = random.choice(nameList)
      aliases[j] += " " + addWord
  return aliases

# %%
T = 0.08
C = 0.1
V = 0.6
Edit_threshold = 2


def generate_permutations(name, rowNumber):
  """ Generate aliases by introducing transcription errors.
      The number of the aliases generated depends by the
      rowNumber parametes """

  words = name.split()
  if "-" in name:
    name = name.replace("-", "")
    words = name.split("-")
  aliases = []
  newT = T

  # The name is made by more than 1 word
  if len(words) > 2:
    for i in range(rowNumber):
      check = True
      for j in range(len(words)):
        
        if j in range(2, len(words)):
          # Remove a word
          if random.random() < C:
            check = False
            alias_without_word = list(words)
            del alias_without_word[j]
            aliases.append(' '.join(alias_without_word))
            break

      if check: aliases.append(name)

  # The name is a single word
  else:
    if random.random() < V:
      ab = random.choice(abbreviation_variations)
      name += " " + random.choice(ab)
      words = name.split()
    aliases = [name for _ in range(rowNumber)]
    newT = T + (T * 0.8)

  # Compute change abbreviations
  # Introduce transcription errors based on T (Temperature) value
  # Introduce variability in companies abbreviations
  
  #if(len(words)) < 3: aliases = introduce_new_words(aliases, Transcription_errors, C + (C * 0.8))

  abbrList = compute_variation_abbreviation(words, Edit_threshold)
  aliases = compute_transcription_errors(aliases, newT)
  aliases = introduce_variability(aliases, abbrList)
  aliases = introduce_white_spaces(aliases, C)

  aliases[0] = name
  return aliases

# %%
generate_permutations("ECO MENTE SRL", 3)
# Out:
# 0.08
# ['ECO MENTE SRL', 'MENTE', 'Company MENTE SRL']

# %%
generate_permutations("AL CAUT AL RUTTI GEN TRD CO LLC POB", 5)
# Out:
# ['AL CAUT AL RUTTI GEN TRD CO LLC POB',
#  'AL CAUT.AL RUTTI GEN TRD/',
#  'AL CAUT AL GEN TRD Comp. LLC POB',
#  'AL CAUT AL RUTTI TRD',
#  'AL CAUT  AL RUTTI GEN TRD CO Public Ltd. POB']

# %%
numAlias = 10

for el in names:
    aliases = generate_permutations(el, numAlias)
    for a in aliases: print(a)
    print()
# Out:
# Roger Legrand S.A.R.L.
# Roger  Legrand SCARL
# Roger Legrand
# Roger-Legrand  SCARL
# Roger Legrand
# Roger Legrand  S.c.a.r.l
# Roger Legrand S.c.a.r.l
# Roger Legrand S.c.a.r.l.
# Roger Legrand S.C.A.R.L.
# Roger Legrand
#
# Krebs Inc.
# Krebs Incorporated
# Krebs  Incorporated
# Krebs Inc.
# Krebs-Inc.
# Krebs  Inc
# Krebs
# Krebs Incorporated
# Krebs Inc
# Krebs Inc
#
# Ropero y Ruano S.C
# Ropero y Ruano
# Ropero y Ruano  .SC
# Ropero y  Ruano S.a.
# Ropero y Ruano S.C.
# Ropero y Ruano/S.c.
# Ropero y Ruano S.c.
# Ropero  y Ruano
# Ropero y  Ruano/
# Ropero y  Ruano S.N.C.
#
# Gemito, Lippomano e Pellico e figli
# Gemito, Lippomano Pellico,e figli
# Gemito, Lippomano  e Pellico figli
# Gemito,,Lippomano e Pellico/e figli
# Gemito, Lippomano Pellico e figli
# Gemito, Lippomano e Pellico e figli
# Gemito, Lippomano e Pellico e figli
# Gemito, Lippomano e Pellico e figli
# Gemito, Lippomano e Pellico - e figli
# Gemito,  Lippomano e Pellico e figli
#
# Scholtz Inc.
# Scholtz Incorporated
# Scholtz
# Scholtz
# Scholtz Incorporated
# Scholtz,
# Scholtz
# Scholtz
# Scholtz
# Scholtz Inc
#
# Reesink SU
# Reesink S.a.
# Reesink S.C.
# Reesink S.U.
# Reesink
# Reesink S.C.
# Reesink
# Reesink S.U.
# Reesink S.c
# Reesink S.c.
#
# Wilmsen Incorporated
# Wilmsen
# Wilmsen
# Wilmsen Inc
# Wilmsen Inc
# Wilmsen Inc
# Wilmsen Inc.
# Wilmsen Inc
# Wilmsen Inc
# Wilmsen  Inc
#
# Huet Cp.
# Huet Co
# Huet.Corp.
# Huet Corpn.
# Huet
# Huet
# Huet. Corpn.
# Huet
# Huet Co
# Huet
#
# Häring
# Häring
# Härin.
# Härin.
# Häring
# Häri.g
# Häring
# Häring
# Häring
# Häring
#
# Manufacturas Iberia S.L.U.
# Manufacturas Iberia S.L.U.
# Manufacturas Iberia  S.L.U.
# Manufacturas Iberia S.L.U.
# Manufacturas Iberia S.L.U.
# Manufacturas Iberia S.L.U.
# Manufacturas Iberia
# Manufacturas Iberia S.L.U.
# Manufacturas Iberia S.L.U.
# Manufacturas Iberia S.L.U.
#
# Pierre Joseph S.A.R.L.
# Pierre Joseph SCARL
# Pierre Joseph
# Pierre Joseph,S.c.a.r.l.
# Pierre Joseph
# Pierre  Joseph
# Pierre Joseph
# Pierre Joseph
# Pierre Joseph
# Pierre - Joseph S.c.a.r.l
#
# Hendriks GbR S.A.P.A
# Hendriks/GbR  S.a.p.a.
# Hendriks GbR
# Hendriks GbR
# Hendriks GbR S.a.p.a
# Hendriks GbR SAPA
# Hendriks GbR SAPA
# Hendriks GbR
# Hendriks GbR S.A.P.A
# Hendriks,GbR
#
# Wulf KG Comp.
# Wulf.KG
# Wulf KG Cp.
# Wulf KG Co
# Wulf KG
# Wulf KG
# Wulf KG
# Wulf KG Corp
# Wulf KG. Cp.
# Wulf KG Co
#
# Hecker Bolander GmbH
# Hecker Bolander GmbH
# Hecker Bolander GmbH
# Hecker Bolander GmbH
# Hecker Bolander GmbH
# Hecker Bolander GmbH
# Hecker Bolander GmbH
# Hecker Bolander GmbH
# Hecker Bolander GmbH
# Hecker.Bolander GmbH
#
# Fernandes
# Fernand,-
# . ernandes
# Fernandes
# Fernandes
# Fernandes
# Ferna  .des
# Fernandes
# Fernandes
# Fernandes
#
# Jackson, Simpson and
# Jackson, Simpson and
# Jackson, Simpson and
# Jackson, Simpson and
# Jackson, Simpson and
# Jackson,/Simpson and
# Jackson, Simpson and
# Jackson, Simpson and
# Jackson, Simpson and
# Jackson, Simpson and
#
# Junk Eberhardt GmbH
# Junk  Eberhardt GmbH
# Junk Eberhardt
# Junk Eberhardt. GmbH
# Junk  Eberhardt
# Junk Eberhardt GmbH
# Junk Eberhardt GmbH
# Junk Eberhardt GmbH
# Junk Eberhardt
# Junk Eberhardt GmbH
#
# Boulay S.N.C.
# Boulay
# Boulay SNC
# Boulay
# Boulay SNC
# Boulay
# Boulay S.N.C.
# Boulay S.N.C.
# Boulay
# Boulay  SNC
#
# Jackson, Simpsonand Richards
# Jackson, Simpsonand Richards
# Jackson, Simpsonand Richards
# Jackson, Simpsonand Richards
# Jackson, Simpsonand Richards
# Jackson, Simpsonand Richards
# Jackson, Simpsonand.Richards
# Jackson, Simpsonand Richards
# Jackson, Simpsonand,Richards
# Jackson, Simpsonand.Richards
#
# Soranzo Group S.a.
# Soranzo Group-S.a.
# Soranzo Group
# Soranzo Group
# Soranzo  .Group
# Soranzo Group,SA
# Soranzo Group
# Soranzo Group
# Soranzo Group-
# Soranzo Group S.a.s.
#
# Rohleder Zänker GmbH & Co. KG
# Rohleder Zänker &
# Rohleder Zänker GmbH  & KG
# Rohleder Zänker GmbH & Co.
# Rohleder Zänker GmbH - &
# Rohleder Zänker GmbH &
# Rohleder Zänker GmbH &  Corp. KG
# Rohleder Zänker GmbH & KG
# Rohleder Zänker GmbH & Corp. .KG
# Rohleder Zänker GmbH & Corpn. KG
#
# Stadelmann S.N.C.
# Stadelmann
# Stadelmann
# Stadelmann S.n.c
# Stadelmann  SNC
# Stadelmann S.N.C
# Stadelmann S.N.C
# Stadelmann. S.N.C
# Stadelmann SNC
# Stadelmann
#
# Andre
# Andre
# Andre
# Andre
# Andre
# Andre
# An. re
# Andre
# Andre
# Andre
#
# Jacques SARL S.R.L.
# Jacques SARL.  S.r.l.
# Jacques SARL S.R.L.
# Jacques .SARL
# Jacques  SARL
# Jacques- Srl S.R.L.
# Jacques SARL-
# Jacques S.r.l. S.R.L.
# Jacques SARL S.r.l.
# Jacques SARL-
#
# Clerc
# Clerc
# Clerc
# Clerc
# Clerc
# Clerc
# Clerc
# Clerc
# Clerc
# Clerc
#
# Hnos Andreu Società per Azioni
# Hnos Andreu Società per Azioni
# Hnos Andreu Società per Azioni
# Hnos Andreu Società per Azioni
# Hnos .Andreu Società per Azioni
# Hnos Andreu-Società per-Azioni
# Hnos Andreu Società per Azioni
# Hnos Andreu Società per Azioni
# Hnos Andreu Società per.Azioni
# Hnos  Andreu. Società per Azioni
#
# Schuster Stiftung. &
# Schuster Stiftung. &
# Schuster Stiftung. &
# Schuster Stiftung. &
# Schuster Stiftung. &
# Schuster Stiftung. &
# Schuster Stiftung./&
# Schuster  Stiftung..&
# Schuster Stiftung. &
# Schuster Stiftung. &
#
# Buchholz GmbH
# Buchholz GmbH
# Buchholz GmbH
# Buchholz GmbH
# Buchholz GmbH
# Buchholz GmbH
# Buchholz GmbH
# Buchholz GmbH
# Buchholz GmbH
# Buchholz GmbH
#
# Schmitt et Fils
# Schmitt et Fils
# Schmitt  et Fils
# Schmitt  et- Fils
# Schmitt et Fils
# Schmitt et
# Schmitt et Fils
# Schmitt et Fils
# Schmitt .et .Fils
# Schmitt et Fils
#
# Fogaça S.c.a.r.l.
# Fogaça SCARL
# Fogaça S.C.A.R.L.
# Fogaça SCARL
# Fogaça
# Fogaça S.c.a.r.l.
# Fogaça
# Fogaça
# Fogaça
# Fogaça SCARL
#
# Dias S.P.A
# Dias  SpA
# Dias SpA
# Dias S.P.A.
# Dias SpA
# Dias
# Dias
# Dias
# Dias SpA
# Dias- SPA
#
# Gosselin S.A.S.
# Gosselin S.a.s.
# Gosselin
# Gosselin  S.a.s.
# Gosselin
# Gosselin
# Gosselin
# Gosselin SAS
# Gosselin
# Gosselin
#
# da Cunha S.A.
# Cunha S.A.
# da Cunha
# S.a. Cunha,S.A.
# da Cunha S.P.A
# S.a Cunha S.A.
# da/Cunha
# da Cunha SPA
# da Cunha/S.P.A.
# da Cunha
#
# Stadelmann
# Stadelmann
# Stadelmann
# Stadelmann
# Stadelmann
# . tadelmann
# Stadelmann
# Stadelmann
# Stadelmann
# Stadelmann
#
# Hnos Andreu S.a.
# Hnos-  Andreu
# Hnos Andreu S.P.A
# Hnos Andreu SAS
# Hnos,Andreu
# Hnos Andreu
# Hnos Andreu
# Hnos Andreu- Società per Azioni
# Hnos Andreu
# Hnos Andreu SA
#
# Ropero y RuanoS.C
# Ropero. y RuanoS.C
# Ropero y RuanoS.C
# Ropero y RuanoS.C
# Ropero y RuanoS.C
# Ropero y RuanoS.C
# Ropero y RuanoS.C
# Ropero y RuanoS.C
# Ropero y RuanoS.C
# Ropero y  RuanoS.C
#
# Karge Atzler AG & Corp KG
# Karge Atzler AG & Corp. KG
# Karge Atzler AG &-Corp KG
# Karge Atzler. AG
# Karge Atzler &
# Karge Atzler,AG & Cp. KG
# Karge Atzler- AG & Cp. KG
# Karge Atzler AG & - Corp KG
# Karge Atzler AG &
# Karge Atzler/AG Corpn. KG
#
# Hnos Andreu SAS
# Hnos Andreu
# Hnos  - Andreu S.a.s
# Hnos Andreu S.a.s.
# Hnos Andreu S.a.s
# Hnos Andreu.
# Hnos Andreu S.A.S
# Hnos Andreu
# Hnos Andreu S.a.s
# Hnos Andreu
#
# Hnos  Andreu S.a.s
# Hnos  Andreu,SAS
# Hnos  Andreu
# Hnos  Andreu S.a.s
# Hnos  Andreu
# Hnos  Andreu SA
# Hnos  Andreu
# Hnos  Andreu SA
# Hnos  Andreu SA
# Hnos  Andreu
#
# Gemito, Lippomano. e Pellico.e figli
# Gemito, Lippomano. e Pellico.e figli
# Gemito, Lippomano. e Pellico.e figli
# Gemito, Lippomano. e Pellico.e,figli
# Gemito, Lippomano. Pellico.e figli
# Gemito, Lippomano. e Pellico.e figli
# Gemito, Lippomano. e Pellico.e-figli
# Gemito, Lippomano. e/Pellico.e figli
# Gemito,- Lippomano. e Pellico.e figli
# Gemito, Lippomano. e Pellico.e figli
#
# Gemito, Lippomano Pellico e figli
# Gemito, Lippomano Pellico e figli
# Gemito, Lippomano Pellico e figli
# Gemito,/Lippomano - Pellico e figli
# Gemito, Lippomano Pellico e figli
# Gemito, Lippomano Pellico figli
# Gemito, Lippomano e figli
# Gemito, Lippomano Pellico e figli
# Gemito,- Lippomano Pellico e
# Gemito, Lippomano Pellico e - figli
#
# Roger Legrand  S.A.R.L.
# Roger Legrand
# Roger Legrand
# Roger Legrand/
# Roger Legrand  -
# Roger Legrand  SCARL
# Roger Legrand--S.C.A.R.L.
# Roger - Legrand- SCARL
# Roger Legrand
# Roger Legrand  S.c.a.r.l.
#
# Gemito,. Lippomano Pellico e/figli
# Gemito,..Lippomano Pellico
# Gemito,. Lippomano Pellico e/figli
# Gemito,. Lippomano  Pellico e/figli
# Gemito,. Lippomano Pellico e/figli
# Gemito,. .Lippomano-  Pellico e/figli
# Gemito,. Lippomano Pellico e/figli
# Gemito,..Lippomano Pellico e/figli
# Gemito,. Lippomano Pellico e/figli
# Gemito,. Lippomano Pellico e/figli
#
# Gemito,Lippomano e Pellico e figli
# Gemito,Lippomano e,Pellico e figli
# Gemito,Lippomano e Pellico e figli
# Gemito,Lippomano. e Pellico.e figli
# Gemito,Lippomano e Pellico e figli
# Gemito,Lippomano e Pellico e figli
# Gemito,Lippomano e Pellico e figli
# Gemito,Lippomano .e Pellico e figli
# Gemito,Lippomano e-Pellico e figli
# Gemito,Lippomano e Pellico/e figli
